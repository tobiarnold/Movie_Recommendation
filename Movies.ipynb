# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Besitzer\Downloads\english_movies.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         10000 non-null  object
#  1   overview      9995 non-null   object
#  2   release_date  9982 non-null   object
#  3   genres        9978 non-null   object
#  4   popularity    10000 non-null  float64
#  5   vote_average  10000 non-null  float64
#  6   vote_count    10000 non-null  int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 547.0+ KB

# %%
df=df.dropna()

# %%
df.head()
# Out:
#                               title  \
# 0                         The Flash
# 1                            Barbie
# 2  Transformers: Rise of the Beasts
# 3                The Little Mermaid
# 4      Ruby Gillman, Teenage Kraken
#
#                                             overview release_date  \
# 0  When his attempt to save his family inadverten...   2023-06-13
# 1  Barbie and Ken are having the time of their li...   2023-07-19
# 2  When a new threat capable of destroying the en...   2023-06-06
# 3  The youngest of King Triton’s daughters, and t...   2023-05-18
# 4  Ruby Gillman, a sweet and awkward high school ...   2023-06-28
#
#                                 genres  popularity  vote_average  vote_count
# 0   Action, Adventure, Science Fiction    4631.142           6.9        1773
# 1           Comedy, Adventure, Fantasy    4493.487           7.6        1621
# 2   Action, Adventure, Science Fiction    4090.661           7.5        2065
# ...

# %%
df.tail()
# Out:
#                  title                                           overview  \
# 9994    Big Buck Bunny  Follow a day of the life of Big Buck Bunny whe...
# 9995       Blood Creek  A man and his brother on a mission of revenge ...
# 9997  Comanche Station  A man saves a woman who had been kidnapped by ...
# 9998              Bait  Martin Ward is a cove fisherman, without a boa...
# 9999         Butterfly  Jess Tyler lives a quiet life next to an aband...
#
#      release_date                     genres  popularity  vote_average  \
# 9994   2008-04-10  Animation, Comedy, Family       6.621           6.5
# 9995   2009-10-09           Horror, Thriller       6.610           5.3
# 9997   1960-03-01                    Western       6.574           6.6
# 9998   2019-03-26                      Drama       6.569           7.0
# 9999   1982-02-05               Crime, Drama       6.479           5.3
#
#       vote_count
# 9994         169
# 9995         223
# 9997          88
# 9998          70
# ...

# %%
df["release_date"] = pd.to_datetime(df["release_date"]).dt.year
df["release_date"] = df["release_date"].astype("int")

# %%
df.head()
# Out:
#                               title  \
# 0                         The Flash
# 1                            Barbie
# 2  Transformers: Rise of the Beasts
# 3                The Little Mermaid
# 4      Ruby Gillman, Teenage Kraken
#
#                                             overview  release_date  \
# 0  When his attempt to save his family inadverten...          2023
# 1  Barbie and Ken are having the time of their li...          2023
# 2  When a new threat capable of destroying the en...          2023
# 3  The youngest of King Triton’s daughters, and t...          2023
# 4  Ruby Gillman, a sweet and awkward high school ...          2023
#
#                                 genres  popularity  vote_average  vote_count
# 0   Action, Adventure, Science Fiction    4631.142           6.9        1773
# 1           Comedy, Adventure, Fantasy    4493.487           7.6        1621
# 2   Action, Adventure, Science Fiction    4090.661           7.5        2065
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9959 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         9959 non-null   object
#  1   overview      9959 non-null   object
#  2   release_date  9959 non-null   int32
#  3   genres        9959 non-null   object
#  4   popularity    9959 non-null   float64
#  5   vote_average  9959 non-null   float64
#  6   vote_count    9959 non-null   int64
# dtypes: float64(2), int32(1), int64(1), object(3)
# memory usage: 583.5+ KB

# %%
print(df["genres"].unique())
# Out:
# ['Action, Adventure, Science Fiction' 'Comedy, Adventure, Fantasy'
#  'Adventure, Family, Fantasy, Romance' ...
#  'TV Movie, Science Fiction, Action'
#  'Drama, Horror, Mystery, Science Fiction' 'Thriller, History, Drama, War']

# %%
unique_genres = df["genres"].unique()
for genre in unique_genres:
    print(genre)
# Out:
# Action, Adventure, Science Fiction
# Comedy, Adventure, Fantasy
# Adventure, Family, Fantasy, Romance
# Animation, Family, Fantasy, Comedy
# Science Fiction, Adventure, Action
# Action, Crime, Thriller
# Action, Drama, War
# Drama, History
# Action, Drama
# Fantasy, Action, Adventure
# Animation, Family, Adventure, Fantasy, Comedy
# Animation, Comedy, Family, Fantasy, Romance
# Action, Adventure, Animation, Science Fiction
# Action, Thriller, Crime
# Horror, Mystery, Thriller
# Horror, Thriller, Comedy
# Thriller, Horror
# Action, Crime, Horror
# Action, Drama, Thriller
# Action, Adventure, Drama
# Romance, Action, Comedy
# Action, Thriller
# Action, Comedy, Crime, Adventure
# Action, Adventure, Thriller
# Action, Science Fiction, Horror
# Mystery, Thriller, Action
# Horror, Crime, Thriller
# Science Fiction, Mystery, Thriller
# Horror, Thriller
# Animation, Action, Science Fiction
# War, Action, Thriller
# Action, Fantasy, Thriller
# ...

# %%
#new_df = df["genres"].str.split(",",expand=True)
#new_df.columns = [f"genre_{i+1}" for i in range(new_df.shape[1])]
#df = pd.concat([df, new_df], axis=1)
#df.head()

# %%
#print(df["genre_1"].unique())

# %%
#df["popularity"].hist()

# %%
print(df["popularity"].min())
print(df["popularity"].max())
# Out:
# 6.479
# 4631.142

# %%
df = df[df["vote_average"] > 0]
#df = df.drop("genres", axis="columns")
df.head()
# Out:
#                               title  \
# 0                         The Flash
# 1                            Barbie
# 2  Transformers: Rise of the Beasts
# 3                The Little Mermaid
# 4      Ruby Gillman, Teenage Kraken
#
#                                             overview  release_date  \
# 0  When his attempt to save his family inadverten...          2023
# 1  Barbie and Ken are having the time of their li...          2023
# 2  When a new threat capable of destroying the en...          2023
# 3  The youngest of King Triton’s daughters, and t...          2023
# 4  Ruby Gillman, a sweet and awkward high school ...          2023
#
#                                 genres  popularity  vote_average  vote_count
# 0   Action, Adventure, Science Fiction    4631.142           6.9        1773
# 1           Comedy, Adventure, Fantasy    4493.487           7.6        1621
# 2   Action, Adventure, Science Fiction    4090.661           7.5        2065
# ...

# %%
df.to_csv("movies.csv", index=False)
